# %%
renv::load("..")
# Out:
# - Project '~/Documents/Coding/clinical-trials' loaded. [renv 1.2.3]

# %%
library(jsonlite)
library(duckdb)
library(DBI)
library(dplyr)
library(tidyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
# Concept record 6347574 always resolves to the latest ROR release
rec <- fromJSON("https://zenodo.org/api/records/6347574", simplifyVector = FALSE)

# Download the zip; the URL ends in /content, libcurl follows the redirect
zip_url <- rec$files[[1]]$links$self
download.file(zip_url, "/Users/joshziel/Documents/Coding/clinical-trials/data/reference/ror/ror-data.zip", mode = "wb", method = "libcurl")
# Out:
# trying URL 'https://zenodo.org/api/records/20512981/files/v2.8-2026-06-02-ror-data.zip/content'
# Content type 'application/octet-stream' length 33075029 bytes (31.5 MB)
# ...
# downloaded 31.5 MB

# %%
rorData <- fromJSON('/Users/joshziel/Documents/Coding/clinical-trials/data/reference/ror/ror-data/v2.8-2026-06-02-ror-data.json')

# %%
rorData$names
# Out:
# [[1]]
#                                                value              types lang
# 1                                               RMIT            acronym <NA>
# 2                                    RMIT University ror_display, label   en
# 3 Royal Melbourne Institute of Technology University              alias   en
#
# [[2]]
#                           value              types lang
# 1                           CQU            acronym <NA>
# 2                  CQUniversity              alias   en
# 3 Central Queensland University ror_display, label   en
#
# [[3]]
#             value              types lang
# 1 Bond University ror_display, label   en
#
# [[4]]
#                      value              types lang
# 1                      CSU            acronym <NA>
# 2 Charles Sturt University ror_display, label   en
#
# [[5]]
#                          value              types lang
# 1                          HRI            acronym <NA>
# ...

# %%
rorNames <- rorData[, c("id", "names")]|>
    unnest(names) |> 
    unnest(types)

# %%
head(rorNames)
# Out:
# # A tibble: 6 × 4
#   id                        value                                              types       lang
#   <chr>                     <chr>                                              <chr>       <chr>
# 1 https://ror.org/04ttjf776 RMIT                                               acronym     NA
# 2 https://ror.org/04ttjf776 RMIT University                                    ror_display en
# 3 https://ror.org/04ttjf776 RMIT University                                    label       en
# 4 https://ror.org/04ttjf776 Royal Melbourne Institute of Technology University alias       en
# 5 https://ror.org/023q4bk22 CQU                                                acronym     NA
# 6 https://ror.org/023q4bk22 CQUniversity                                       alias       en

# %%
# Out:
# NULL
